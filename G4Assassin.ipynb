# %%
print('   ___ _  _     _                         _       \n  / _ \ || |   /_\  ___ ___  __ _ ___ ___(_)_ __  \n / /_\/ || |_ //_\\/ __/ __|/ _` / __/ __| | _ \ \n/ /_\\|__   _/  _  \__ \__ \ (_| \__ \__ \ | | | |\n\____/   |_| \_/ \_/___/___/\___|___/___/_|_| |_|\n\n')
# Out:
#    ___ _  _     _                         _
#   / _ \ || |   /_\  ___ ___  __ _ ___ ___(_)_ __
#  / /_\/ || |_ //_\/ __/ __|/ _` / __/ __| | _ \
# / /_\|__   _/  _  \__ \__ \ (_| \__ \__ \ | | | |
# \____/   |_| \_/ \_/___/___/\___|___/___/_|_| |_|

# %%
import pandas as pd
import os
import glob
from Bio import SeqIO
import subprocess
fastaFile = 'Genomes/DOUBLETESTER.fasta'
Mito = 'Mitochondria_NC_012920_1.fasta'
GENOMES = 'FINAL/'

#Global integers
WINDOWVAL = 25
THRESHOLDVAL = 1.2


# Global strings
G4HUNTER = 'G4HunterEDITED.py'


# Output stats globals
WINDOW = 'Window'
THRESHOLD = 'Threshold'
NPQS = 'Number of PQS'
BP = 'Base Pairs'
NGC = 'Number of GCs'
PGC = 'Percentage of GCs'
FRQ = 'Frequency of PQS'

# G4 Result .txt file to Database Globals
SEQ_ID = 'Sequence_ID'
START = 'Start'
END = 'End'
SEQUENCE = 'Sequence'
LENGTH = 'Length'
SCORE = 'Score'

# %%
# Functions
def process_txt_file(file_path):
    data = []
    current_sequence = None
    PQS = 0
    
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            
            # If the line starts with '>', it indicates a new sequence section
            if line.startswith('>'):
                current_sequence = line[1:]  # Remove '>' and store the sequence identifier
            elif line and not line.startswith(START):
                # Process the data lines
                parts = line.split()
                if len(parts) == 5:  # Ensures correct number of columns
                    start, end, sequence, length, score = parts
                    data.append({
                        SEQ_ID: current_sequence,
                        START: int(start),
                        END: int(end),
                        SEQUENCE: sequence,
                        LENGTH: int(length),
                        SCORE: float(score)
                    })
                elif len(parts) == 6:  # Ensures correct number of columns
                    start, end, sequence, length, score, nbr = parts
                    data.append({
                        SEQ_ID: current_sequence,
                        START: int(start),
                        END: int(end),
                        SEQUENCE: sequence,
                        LENGTH: int(length),
                        SCORE: float(score)
                    })
                    
                    PQS += int(nbr) # Save number of putative quadruplex sequences
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(data)
    return df, PQS

def runG4(inputFile):
    print('Running G4Hunter:', inputFile)
    result = subprocess.run(
    ['python3', G4HUNTER, '-i', inputFile, '-o', 'Results', '-w', str(WINDOWVAL), '-s', str(THRESHOLDVAL)],
                        capture_output=True, text=True)
    return result.stdout.strip()


def overallStats(filePath):
    outputStats = {NPQS:0, BP: 0, NGC:0, PGC:0.0, FRQ: 0.0, WINDOW:WINDOWVAL, THRESHOLD:THRESHOLDVAL}
    
    # Parse all sequences in the file
    for record in SeqIO.parse(filePath, "fasta"):
        sequence = record.seq.upper()  # Convert to uppercase
        outputStats[BP] += len(sequence)
        outputStats[NGC] += sequence.count("G") + sequence.count("C")
    return outputStats

def findFastaFiles(directory):
    # Define the FASTA file extensions you want to search for
    fastaExtensions = ['*.fasta', '*.fa', '*.fna', '*.ffn', '*.faa', '*.frn']
    
    # Initialize an empty list to store the file paths
    fastaFiles = []
    
    # Iterate over each file extension pattern
    for ext in fastaExtensions:
        # Use glob to search for files matching the pattern within the directory and its subdirectories
        files = glob.glob(os.path.join(directory, '**', ext), recursive=True)
        # Append found files to the list
        fastaFiles.extend(files)
    
    return fastaFiles

def main(filePath):
    return runG4(filePath), overallStats(filePath)




# Main Function

def assassinate(filePath):
    
    # Make list of all files, iterate, produce the filepath and stats, save the overall stats 
    # in the same folder as the generated file path. 
    
    for file in findFastaFiles(filePath):
        print('Processing:', file)
        generatedFilepath, overallStats = main(file)
        overallStats[NPQS] = process_txt_file(generatedFilepath)[1]
        overallStats[PGC] = overallStats[NGC]/overallStats[BP]
        overallStats[FRQ] = overallStats[NPQS]/overallStats[BP]
        
        
        # Save output data
        directory = os.path.dirname(generatedFilepath)
        base_name = os.path.splitext(os.path.basename(generatedFilepath))[0]
        csv_file_name = f"{base_name}.csv"
        csv_file_path = os.path.join(directory, csv_file_name)
        df = pd.DataFrame([overallStats])
        df.to_csv(csv_file_path, index=False)
        print('Saved to', csv_file_path)
    
    return

# %%
'''result = subprocess.run(
    ['python3', G4HUNTER, '-i', fasta_file, '-o', 'Results', '-w', str(WINDOW), '-s', str(THRESHHOLD)],
                        capture_output=True, text=True)
generated_filepath = result.stdout.strip()'''

'''generatedFilepath = runG4(fastaFile)
print(generatedFilepath)
print(process_txt_file(generatedFilepath))'''

assassinate(GENOMES)

#sequences = list(SeqIO.parse(fastaFile, "fasta"))
# Out:
# Processing: FINAL/Leishmania/GCA_963920605.1/GCA_963920605.1_Parent1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_963920605.1/GCA_963920605.1_Parent1_genomic.fna
# Saved to Results/Results_GCA_963920605/GCA_963920605-Merged.csv
# Processing: FINAL/Leishmania/GCF_000002725.2/GCF_000002725.2_ASM272v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000002725.2/GCF_000002725.2_ASM272v2_genomic.fna
# Saved to Results/Results_GCF_000002725/GCF_000002725-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178345.1/GCA_037178345.1_ASM3717834v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178345.1/GCA_037178345.1_ASM3717834v1_genomic.fna
# Saved to Results/Results_GCA_037178345/GCA_037178345-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177955.1/GCA_037177955.1_ASM3717795v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177955.1/GCA_037177955.1_ASM3717795v1_genomic.fna
# Saved to Results/Results_GCA_037177955/GCA_037177955-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178005.1/GCA_037178005.1_ASM3717800v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178005.1/GCA_037178005.1_ASM3717800v1_genomic.fna
# Saved to Results/Results_GCA_037178005/GCA_037178005-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178515.1/GCA_037178515.1_ASM3717851v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178515.1/GCA_037178515.1_ASM3717851v1_genomic.fna
# Saved to Results/Results_GCA_037178515/GCA_037178515-Merged.csv
# Processing: FINAL/Leishmania/GCA_020783415.1/GCA_020783415.1_ASM2078341v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_020783415.1/GCA_020783415.1_ASM2078341v1_genomic.fna
# Saved to Results/Results_GCA_020783415/GCA_020783415-Merged.csv
# Processing: FINAL/Leishmania/GCF_017916325.1/GCF_017916325.1_LU_Lmar_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_017916325.1/GCF_017916325.1_LU_Lmar_1.0_genomic.fna
# Saved to Results/Results_GCF_017916325/GCF_017916325-Merged.csv
# Processing: FINAL/Leishmania/GCA_011316065.1/GCA_011316065.1_ASM1131606v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_011316065.1/GCA_011316065.1_ASM1131606v1_genomic.fna
# Saved to Results/Results_GCA_011316065/GCA_011316065-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178045.1/GCA_037178045.1_ASM3717804v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178045.1/GCA_037178045.1_ASM3717804v1_genomic.fna
# Saved to Results/Results_GCA_037178045/GCA_037178045-Merged.csv
# Processing: FINAL/Leishmania/GCA_902498725.1/GCA_902498725.1_Lma_mini_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902498725.1/GCA_902498725.1_Lma_mini_genomic.fna
# Saved to Results/Results_GCA_902498725/GCA_902498725-Merged.csv
# Processing: FINAL/Leishmania/GCF_000227135.1/GCF_000227135.1_ASM22713v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000227135.1/GCF_000227135.1_ASM22713v2_genomic.fna
# Saved to Results/Results_GCF_000227135/GCF_000227135-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178305.1/GCA_037178305.1_ASM3717830v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178305.1/GCA_037178305.1_ASM3717830v1_genomic.fna
# Saved to Results/Results_GCA_037178305/GCA_037178305-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177915.1/GCA_037177915.1_ASM3717791v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177915.1/GCA_037177915.1_ASM3717791v1_genomic.fna
# Saved to Results/Results_GCA_037177915/GCA_037177915-Merged.csv
# Processing: FINAL/Leishmania/GCA_003304975.1/GCA_003304975.1_IOC-L_3564_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003304975.1/GCA_003304975.1_IOC-L_3564_genomic.fna
# Saved to Results/Results_GCA_003304975/GCA_003304975-Merged.csv
# Processing: FINAL/Leishmania/GCA_001989955.1/GCA_001989955.1_ASM198995v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_001989955.1/GCA_001989955.1_ASM198995v1_genomic.fna
# Saved to Results/Results_GCA_001989955/GCA_001989955-Merged.csv
# Processing: FINAL/Leishmania/GCA_003664525.1/GCA_003664525.1_ASM366452v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003664525.1/GCA_003664525.1_ASM366452v1_genomic.fna
# Saved to Results/Results_GCA_003664525/GCA_003664525-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178145.1/GCA_037178145.1_ASM3717814v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178145.1/GCA_037178145.1_ASM3717814v1_genomic.fna
# Saved to Results/Results_GCA_037178145/GCA_037178145-Merged.csv
# Processing: FINAL/Leishmania/GCA_009770625.1/GCA_009770625.1_UL_Ltar_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_009770625.1/GCA_009770625.1_UL_Ltar_1.0_genomic.fna
# Saved to Results/Results_GCA_009770625/GCA_009770625-Merged.csv
# Processing: FINAL/Leishmania/GCA_009731335.1/GCA_009731335.1_Lta_assembly01_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_009731335.1/GCA_009731335.1_Lta_assembly01_genomic.fna
# Saved to Results/Results_GCA_009731335/GCA_009731335-Merged.csv
# Processing: FINAL/Leishmania/GCA_018291365.1/GCA_018291365.1_IEC_LinfBR_2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_018291365.1/GCA_018291365.1_IEC_LinfBR_2_genomic.fna
# Saved to Results/Results_GCA_018291365/GCA_018291365-Merged.csv
# Processing: FINAL/Leishmania/GCF_017916335.1/GCF_017916335.1_LU_Lori_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_017916335.1/GCF_017916335.1_LU_Lori_1.0_genomic.fna
# Saved to Results/Results_GCF_017916335/GCF_017916335-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178315.1/GCA_037178315.1_ASM3717831v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178315.1/GCA_037178315.1_ASM3717831v1_genomic.fna
# Saved to Results/Results_GCA_037178315/GCA_037178315-Merged.csv
# Processing: FINAL/Leishmania/GCA_902369385.1/GCA_902369385.1_LmjF_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902369385.1/GCA_902369385.1_LmjF_genomic.fna
# Saved to Results/Results_GCA_902369385/GCA_902369385-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177905.1/GCA_037177905.1_ASM3717790v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177905.1/GCA_037177905.1_ASM3717790v1_genomic.fna
# Saved to Results/Results_GCA_037177905/GCA_037177905-Merged.csv
# Processing: FINAL/Leishmania/GCA_040363635.1/GCA_040363635.1_ASM4036363v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_040363635.1/GCA_040363635.1_ASM4036363v1_genomic.fna
# Saved to Results/Results_GCA_040363635/GCA_040363635-Merged.csv
# Processing: FINAL/Leishmania/GCF_000002845.2/GCF_000002845.2_ASM284v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000002845.2/GCF_000002845.2_ASM284v2_genomic.fna
# Saved to Results/Results_GCF_000002845/GCF_000002845-Merged.csv
# Processing: FINAL/Leishmania/GCA_962240435.1/GCA_962240435.1_Llindenbergi_IOCL2690_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_962240435.1/GCA_962240435.1_Llindenbergi_IOCL2690_genomic.fna
# Saved to Results/Results_GCA_962240435/GCA_962240435-Merged.csv
# Processing: FINAL/Leishmania/GCA_002243465.1/GCA_002243465.1_ASM224346v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_002243465.1/GCA_002243465.1_ASM224346v1_genomic.fna
# Saved to Results/Results_GCA_002243465/GCA_002243465-Merged.csv
# Processing: FINAL/Leishmania/GCA_003671315.1/GCA_003671315.1_HUUFS14_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003671315.1/GCA_003671315.1_HUUFS14_genomic.fna
# Saved to Results/Results_GCA_003671315/GCA_003671315-Merged.csv
# Processing: FINAL/Leishmania/GCA_001403675.1/GCA_001403675.1_Leishmania_peruviana_PAB-4377_V1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_001403675.1/GCA_001403675.1_Leishmania_peruviana_PAB-4377_V1_genomic.fna
# Saved to Results/Results_GCA_001403675/GCA_001403675-Merged.csv
# Processing: FINAL/Leishmania/GCA_017918225.1/GCA_017918225.1_LU_LNam_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_017918225.1/GCA_017918225.1_LU_LNam_1.0_genomic.fna
# Saved to Results/Results_GCA_017918225/GCA_017918225-Merged.csv
# Processing: FINAL/Leishmania/GCA_017916305.1/GCA_017916305.1_LU_Lenr_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_017916305.1/GCA_017916305.1_LU_Lenr_1.0_genomic.fna
# Saved to Results/Results_GCA_017916305/GCA_017916305-Merged.csv
# Processing: FINAL/Leishmania/GCA_962239345.1/GCA_962239345.1_Lnaiffi_IOCL1365_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_962239345.1/GCA_962239345.1_Lnaiffi_IOCL1365_genomic.fna
# Saved to Results/Results_GCA_962239345/GCA_962239345-Merged.csv
# Processing: FINAL/Leishmania/GCA_000409445.2/GCA_000409445.2_Leishmania_MAR_LEM2494-1.0.3_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000409445.2/GCA_000409445.2_Leishmania_MAR_LEM2494-1.0.3_genomic.fna
# Saved to Results/Results_GCA_000409445/GCA_000409445-Merged.csv
# Processing: FINAL/Leishmania/GCA_040363675.1/GCA_040363675.1_ASM4036367v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_040363675.1/GCA_040363675.1_ASM4036367v1_genomic.fna
# Saved to Results/Results_GCA_040363675/GCA_040363675-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177945.1/GCA_037177945.1_ASM3717794v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177945.1/GCA_037177945.1_ASM3717794v1_genomic.fna
# Saved to Results/Results_GCA_037177945/GCA_037177945-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178015.1/GCA_037178015.1_ASM3717801v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178015.1/GCA_037178015.1_ASM3717801v1_genomic.fna
# Saved to Results/Results_GCA_037178015/GCA_037178015-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178505.1/GCA_037178505.1_ASM3717850v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178505.1/GCA_037178505.1_ASM3717850v1_genomic.fna
# Saved to Results/Results_GCA_037178505/GCA_037178505-Merged.csv
# Processing: FINAL/Leishmania/GCA_000002875.2/GCA_000002875.2_ASM287v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000002875.2/GCA_000002875.2_ASM287v2_genomic.fna
# Saved to Results/Results_GCA_000002875/GCA_000002875-Merged.csv
# Processing: FINAL/Leishmania/GCA_000438535.1/GCA_000438535.1_LeiAma1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000438535.1/GCA_000438535.1_LeiAma1.0_genomic.fna
# Saved to Results/Results_GCA_000438535/GCA_000438535-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178405.1/GCA_037178405.1_ASM3717840v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178405.1/GCA_037178405.1_ASM3717840v1_genomic.fna
# Saved to Results/Results_GCA_037178405/GCA_037178405-Merged.csv
# Processing: FINAL/Leishmania/GCA_000443025.1/GCA_000443025.1_Leishmania_gerbilii_LEM452-1.0.2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000443025.1/GCA_000443025.1_Leishmania_gerbilii_LEM452-1.0.2_genomic.fna
# Saved to Results/Results_GCA_000443025/GCA_000443025-Merged.csv
# Processing: FINAL/Leishmania/GCA_020705095.1/GCA_020705095.1_ASM2070509v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_020705095.1/GCA_020705095.1_ASM2070509v1_genomic.fna
# Saved to Results/Results_GCA_020705095/GCA_020705095-Merged.csv
# Processing: FINAL/Leishmania/GCA_000340495.1/GCA_000340495.1_Leishmania_panamensis_L13-1.3.1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000340495.1/GCA_000340495.1_Leishmania_panamensis_L13-1.3.1_genomic.fna
# Saved to Results/Results_GCA_000340495/GCA_000340495-Merged.csv
# Processing: FINAL/Leishmania/GCA_000441995.1/GCA_000441995.1_Leishmania_turanica_LEM423-1.0.2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000441995.1/GCA_000441995.1_Leishmania_turanica_LEM423-1.0.2_genomic.fna
# Saved to Results/Results_GCA_000441995/GCA_000441995-Merged.csv
# Processing: FINAL/Leishmania/GCA_902369275.1/GCA_902369275.1_Lbraz_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902369275.1/GCA_902369275.1_Lbraz_genomic.fna
# Saved to Results/Results_GCA_902369275/GCA_902369275-Merged.csv
# Processing: FINAL/Leishmania/GCA_003664395.1/GCA_003664395.1_CDC_Llain_216-34_v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003664395.1/GCA_003664395.1_CDC_Llain_216-34_v1_genomic.fna
# Saved to Results/Results_GCA_003664395/GCA_003664395-Merged.csv
# Processing: FINAL/Leishmania/GCA_902369335.1/GCA_902369335.1_Linf_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902369335.1/GCA_902369335.1_Linf_genomic.fna
# Saved to Results/Results_GCA_902369335/GCA_902369335-Merged.csv
# Processing: FINAL/Leishmania/GCA_000340355.2/GCA_000340355.2_Leishmania_braziliensis_M2903-1.0.6_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000340355.2/GCA_000340355.2_Leishmania_braziliensis_M2903-1.0.6_genomic.fna
# Saved to Results/Results_GCA_000340355/GCA_000340355-Merged.csv
# Processing: FINAL/Leishmania/GCA_001403695.1/GCA_001403695.1_Leishmania_peruviana_LEM-1537_V1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_001403695.1/GCA_001403695.1_Leishmania_peruviana_LEM-1537_V1_genomic.fna
# Saved to Results/Results_GCA_001403695/GCA_001403695-Merged.csv
# Processing: FINAL/Leishmania/GCA_024970365.1/GCA_024970365.1_ASM2497036v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_024970365.1/GCA_024970365.1_ASM2497036v1_genomic.fna
# Saved to Results/Results_GCA_024970365/GCA_024970365-Merged.csv
# Processing: FINAL/Leishmania/GCA_003992435.1/GCA_003992435.1_ASM399243v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003992435.1/GCA_003992435.1_ASM399243v1_genomic.fna
# Saved to Results/Results_GCA_003992435/GCA_003992435-Merged.csv
# Processing: FINAL/Leishmania/GCA_000410715.1/GCA_000410715.1_Leishmania_tropica_L590-2.0.2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000410715.1/GCA_000410715.1_Leishmania_tropica_L590-2.0.2_genomic.fna
# Saved to Results/Results_GCA_000410715/GCA_000410715-Merged.csv
# Processing: FINAL/Leishmania/GCA_003730175.1/GCA_003730175.1_ASM373017v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003730175.1/GCA_003730175.1_ASM373017v1_genomic.fna
# Saved to Results/Results_GCA_003730175/GCA_003730175-Merged.csv
# Processing: FINAL/Leishmania/GCA_000227135.2/GCA_000227135.2_ASM22713v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000227135.2/GCA_000227135.2_ASM22713v2_genomic.fna
# Saved to Results/Results_GCA_000227135/GCA_000227135-Merged.csv
# Processing: FINAL/Leishmania/GCA_900500625.2/GCA_900500625.2_LINF_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_900500625.2/GCA_900500625.2_LINF_genomic.fna
# Saved to Results/Results_GCA_900500625/GCA_900500625-Merged.csv
# Processing: FINAL/Leishmania/GCA_003067545.1/GCA_003067545.1_MHOM_LB_2017_IK_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003067545.1/GCA_003067545.1_MHOM_LB_2017_IK_genomic.fna
# Saved to Results/Results_GCA_003067545/GCA_003067545-Merged.csv
# Processing: FINAL/Leishmania/GCA_000410695.2/GCA_000410695.2_Leishmania_arabica_LEM1108-1.0.3_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000410695.2/GCA_000410695.2_Leishmania_arabica_LEM1108-1.0.3_genomic.fna
# Saved to Results/Results_GCA_000410695/GCA_000410695-Merged.csv
# Processing: FINAL/Leishmania/GCF_000755165.1/GCF_000755165.1_ASM75516v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000755165.1/GCF_000755165.1_ASM75516v1_genomic.fna
# Saved to Results/Results_GCF_000755165/GCF_000755165-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178385.1/GCA_037178385.1_ASM3717838v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178385.1/GCA_037178385.1_ASM3717838v1_genomic.fna
# Saved to Results/Results_GCA_037178385/GCA_037178385-Merged.csv
# Processing: FINAL/Leishmania/GCA_902369315.1/GCA_902369315.1_Lgu_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902369315.1/GCA_902369315.1_Lgu_genomic.fna
# Saved to Results/Results_GCA_902369315/GCA_902369315-Merged.csv
# Processing: FINAL/Leishmania/GCA_000444285.2/GCA_000444285.2_Leishmania_aethiopica-L147-2.0.3_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000444285.2/GCA_000444285.2_Leishmania_aethiopica-L147-2.0.3_genomic.fna
# Saved to Results/Results_GCA_000444285/GCA_000444285-Merged.csv
# Processing: FINAL/Leishmania/GCA_003992505.1/GCA_003992505.1_ASM399250v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003992505.1/GCA_003992505.1_ASM399250v1_genomic.fna
# Saved to Results/Results_GCA_003992505/GCA_003992505-Merged.csv
# Processing: FINAL/Leishmania/GCA_964014045.1/GCA_964014045.1_Leishmania_braziliensis_M2904-Dec2022_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_964014045.1/GCA_964014045.1_Leishmania_braziliensis_M2904-Dec2022_genomic.fna
# Saved to Results/Results_GCA_964014045/GCA_964014045-Merged.csv
# Processing: FINAL/Leishmania/GCA_000755165.1/GCA_000755165.1_ASM75516v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000755165.1/GCA_000755165.1_ASM75516v1_genomic.fna
# Saved to Results/Results_GCA_000755165/GCA_000755165-Merged.csv
# Processing: FINAL/Leishmania/GCA_000250755.2/GCA_000250755.2_Leishmania_major_SD_75.1-1.1.1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000250755.2/GCA_000250755.2_Leishmania_major_SD_75.1-1.1.1_genomic.fna
# Saved to Results/Results_GCA_000250755/GCA_000250755-Merged.csv
# Processing: FINAL/Leishmania/GCA_000331345.1/GCA_000331345.1_Leishmania_major_LV39c5-1.0.1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000331345.1/GCA_000331345.1_Leishmania_major_LV39c5-1.0.1_genomic.fna
# Saved to Results/Results_GCA_000331345/GCA_000331345-Merged.csv
# Processing: FINAL/Leishmania/GCA_900537975.2/GCA_900537975.2_LBRM_annotationDEFINITIVO_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_900537975.2/GCA_900537975.2_LBRM_annotationDEFINITIVO_genomic.fna
# Saved to Results/Results_GCA_900537975/GCA_900537975-Merged.csv
# Processing: FINAL/Leishmania/GCA_003992445.1/GCA_003992445.1_ASM399244v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003992445.1/GCA_003992445.1_ASM399244v1_genomic.fna
# Saved to Results/Results_GCA_003992445/GCA_003992445-Merged.csv
# Processing: FINAL/Leishmania/GCA_916722125.1/GCA_916722125.1_LMJFC_annotationDEFINITIVO_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_916722125.1/GCA_916722125.1_LMJFC_annotationDEFINITIVO_genomic.fna
# Saved to Results/Results_GCA_916722125/GCA_916722125-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178585.1/GCA_037178585.1_ASM3717858v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178585.1/GCA_037178585.1_ASM3717858v1_genomic.fna
# Saved to Results/Results_GCA_037178585/GCA_037178585-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178095.1/GCA_037178095.1_ASM3717809v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178095.1/GCA_037178095.1_ASM3717809v1_genomic.fna
# Saved to Results/Results_GCA_037178095/GCA_037178095-Merged.csv
# Processing: FINAL/Leishmania/GCA_014466975.1/GCA_014466975.1_ASM1446697v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_014466975.1/GCA_014466975.1_ASM1446697v1_genomic.fna
# Saved to Results/Results_GCA_014466975/GCA_014466975-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178195.1/GCA_037178195.1_ASM3717819v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178195.1/GCA_037178195.1_ASM3717819v1_genomic.fna
# Saved to Results/Results_GCA_037178195/GCA_037178195-Merged.csv
# Processing: FINAL/Leishmania/GCA_000470725.1/GCA_000470725.1_BHU1220_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000470725.1/GCA_000470725.1_BHU1220_genomic.fna
# Saved to Results/Results_GCA_000470725/GCA_000470725-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178485.1/GCA_037178485.1_ASM3717848v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178485.1/GCA_037178485.1_ASM3717848v1_genomic.fna
# Saved to Results/Results_GCA_037178485/GCA_037178485-Merged.csv
# Processing: FINAL/Leishmania/GCA_030937385.1/GCA_030937385.1_OSU_LamaLV79_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_030937385.1/GCA_030937385.1_OSU_LamaLV79_genomic.fna
# Saved to Results/Results_GCA_030937385/GCA_030937385-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178395.1/GCA_037178395.1_ASM3717839v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178395.1/GCA_037178395.1_ASM3717839v1_genomic.fna
# Saved to Results/Results_GCA_037178395/GCA_037178395-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177985.1/GCA_037177985.1_ASM3717798v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177985.1/GCA_037177985.1_ASM3717798v1_genomic.fna
# Saved to Results/Results_GCA_037177985/GCA_037177985-Merged.csv
# Processing: FINAL/Leishmania/GCA_902369305.1/GCA_902369305.1_Lad_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_902369305.1/GCA_902369305.1_Lad_genomic.fna
# Saved to Results/Results_GCA_902369305/GCA_902369305-Merged.csv
# Processing: FINAL/Leishmania/GCA_037177885.1/GCA_037177885.1_ASM3717788v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037177885.1/GCA_037177885.1_ASM3717788v1_genomic.fna
# Saved to Results/Results_GCA_037177885/GCA_037177885-Merged.csv
# Processing: FINAL/Leishmania/GCA_003730215.1/GCA_003730215.1_ASM373021v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003730215.1/GCA_003730215.1_ASM373021v1_genomic.fna
# Saved to Results/Results_GCA_003730215/GCA_003730215-Merged.csv
# Processing: FINAL/Leishmania/GCA_964014055.1/GCA_964014055.1_Leishmania_braziliensis_M2903-Dec2022_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_964014055.1/GCA_964014055.1_Leishmania_braziliensis_M2903-Dec2022_genomic.fna
# Saved to Results/Results_GCA_964014055/GCA_964014055-Merged.csv
# Processing: FINAL/Leishmania/GCF_000234665.1/GCF_000234665.1_ASM23466v4_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000234665.1/GCF_000234665.1_ASM23466v4_genomic.fna
# Saved to Results/Results_GCF_000234665/GCF_000234665-Merged.csv
# Processing: FINAL/Leishmania/GCA_014466935.1/GCA_014466935.1_ASM1446693v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_014466935.1/GCA_014466935.1_ASM1446693v1_genomic.fna
# Saved to Results/Results_GCA_014466935/GCA_014466935-Merged.csv
# Processing: FINAL/Leishmania/GCA_003020905.1/GCA_003020905.1_ASM302090v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003020905.1/GCA_003020905.1_ASM302090v1_genomic.fna
# Saved to Results/Results_GCA_003020905/GCA_003020905-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178065.1/GCA_037178065.1_ASM3717806v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178065.1/GCA_037178065.1_ASM3717806v1_genomic.fna
# Saved to Results/Results_GCA_037178065/GCA_037178065-Merged.csv
# Processing: FINAL/Leishmania/GCF_000002875.2/GCF_000002875.2_ASM287v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCF_000002875.2/GCF_000002875.2_ASM287v2_genomic.fna
# Saved to Results/Results_GCF_000002875/GCF_000002875-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178225.1/GCA_037178225.1_ASM3717822v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178225.1/GCA_037178225.1_ASM3717822v1_genomic.fna
# Saved to Results/Results_GCA_037178225/GCA_037178225-Merged.csv
# Processing: FINAL/Leishmania/GCA_001989975.1/GCA_001989975.1_ASM198997v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_001989975.1/GCA_001989975.1_ASM198997v1_genomic.fna
# Saved to Results/Results_GCA_001989975/GCA_001989975-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178165.1/GCA_037178165.1_ASM3717816v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178165.1/GCA_037178165.1_ASM3717816v1_genomic.fna
# Saved to Results/Results_GCA_037178165/GCA_037178165-Merged.csv
# Processing: FINAL/Leishmania/GCA_962243165.1/GCA_962243165.1_Lshawi_IOCL3481_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_962243165.1/GCA_962243165.1_Lshawi_IOCL3481_genomic.fna
# Saved to Results/Results_GCA_962243165/GCA_962243165-Merged.csv
# Processing: FINAL/Leishmania/GCA_022701395.1/GCA_022701395.1_ASM2270139v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_022701395.1/GCA_022701395.1_ASM2270139v1_genomic.fna
# Saved to Results/Results_GCA_022701395/GCA_022701395-Merged.csv
# Processing: FINAL/Leishmania/GCA_000234665.4/GCA_000234665.4_ASM23466v4_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000234665.4/GCA_000234665.4_ASM23466v4_genomic.fna
# Saved to Results/Results_GCA_000234665/GCA_000234665-Merged.csv
# Processing: FINAL/Leishmania/GCA_023158965.1/GCA_023158965.1_ASM2315896v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_023158965.1/GCA_023158965.1_ASM2315896v1_genomic.fna
# Saved to Results/Results_GCA_023158965/GCA_023158965-Merged.csv
# Processing: FINAL/Leishmania/GCA_040363645.1/GCA_040363645.1_ASM4036364v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_040363645.1/GCA_040363645.1_ASM4036364v1_genomic.fna
# Saved to Results/Results_GCA_040363645/GCA_040363645-Merged.csv
# Processing: FINAL/Leishmania/GCA_003352575.1/GCA_003352575.1_MHOM_LB_2015_IK_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_003352575.1/GCA_003352575.1_MHOM_LB_2015_IK_genomic.fna
# Saved to Results/Results_GCA_003352575/GCA_003352575-Merged.csv
# Processing: FINAL/Leishmania/GCA_037178365.1/GCA_037178365.1_ASM3717836v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_037178365.1/GCA_037178365.1_ASM3717836v1_genomic.fna
# Saved to Results/Results_GCA_037178365/GCA_037178365-Merged.csv
# Processing: FINAL/Leishmania/GCA_017916335.1/GCA_017916335.1_LU_Lori_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_017916335.1/GCA_017916335.1_LU_Lori_1.0_genomic.fna
# Saved to Results/Results_GCA_017916335/GCA_017916335-Merged.csv
# Processing: FINAL/Leishmania/GCA_017918215.1/GCA_017918215.1_LU_Lgha_1.0_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_017918215.1/GCA_017918215.1_LU_Lgha_1.0_genomic.fna
# Saved to Results/Results_GCA_017918215/GCA_017918215-Merged.csv
# Processing: FINAL/Leishmania/GCA_040363505.1/GCA_040363505.1_ASM4036350v1_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_040363505.1/GCA_040363505.1_ASM4036350v1_genomic.fna
# Saved to Results/Results_GCA_040363505/GCA_040363505-Merged.csv
# Processing: FINAL/Leishmania/GCA_024505685.1/GCA_024505685.1_BA788_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_024505685.1/GCA_024505685.1_BA788_genomic.fna
# Saved to Results/Results_GCA_024505685/GCA_024505685-Merged.csv
# Processing: FINAL/Leishmania/GCA_000002845.2/GCA_000002845.2_ASM284v2_genomic.fna
# Running G4Hunter: FINAL/Leishmania/GCA_000002845.2/GCA_000002845.2_ASM284v2_genomic.fna
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 10>()
#       1 '''result = subprocess.run(
#       2     ['python3', G4HUNTER, '-i', fasta_file, '-o', 'Results', '-w', str(WINDOW), '-s', str(THRESHHOLD)],
#       3                         capture_output=True, text=True)
#       4 generated_filepath = result.stdout.strip()'''
#       6 '''generatedFilepath = runG4(fastaFile)
#       7 print(generatedFilepath)
#       8 print(process_txt_file(generatedFilepath))'''
# ---> 10 assassinate(GENOMES)
#
# Input In [3], in assassinate(filePath)
#      91 for file in findFastaFiles(filePath):
#      92     print('Processing:', file)
# ---> 93     generatedFilepath, overallStats = main(file)
#      94     overallStats[NPQS] = process_txt_file(generatedFilepath)[1]
#      95     overallStats[PGC] = overallStats[NGC]/overallStats[BP]
#
# Input In [3], in main(filePath)
#      78 def main(filePath):
# ---> 79     return runG4(filePath), overallStats(filePath)
#
# Input In [3], in runG4(inputFile)
#      44 def runG4(inputFile):
#      45     print('Running G4Hunter:', inputFile)
# ---> 46     result = subprocess.run(
#      47     ['python3', G4HUNTER, '-i', inputFile, '-o', 'Results', '-w', str(WINDOWVAL), '-s', str(THRESHOLDVAL)],
#      48                         capture_output=True, text=True)
#      49     return result.stdout.strip()
#
# File ~/opt/anaconda3/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File ~/opt/anaconda3/lib/python3.9/subprocess.py:1134, in Popen.communicate(self, input, timeout)
#    1131     endtime = None
#    1133 try:
# -> 1134     stdout, stderr = self._communicate(input, endtime, timeout)
#    1135 except KeyboardInterrupt:
#    1136     # https://bugs.python.org/issue25942
#    1137     # See the detailed comment in .wait().
#    1138     if timeout is not None:
#
# File ~/opt/anaconda3/lib/python3.9/subprocess.py:1979, in Popen._communicate(self, input, endtime, orig_timeout)
#    1972     self._check_timeout(endtime, orig_timeout,
#    1973                         stdout, stderr,
#    1974                         skip_check_and_raise=True)
#    1975     raise RuntimeError(  # Impossible :)
#    1976         '_check_timeout(..., skip_check_and_raise=True) '
#    1977         'failed to raise TimeoutExpired.')
# -> 1979 ready = selector.select(timeout)
#    1980 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1982 # XXX Rewrite these to use non-blocking I/O on the file
#    1983 # objects; they are no longer using C stdio!
#
# File ~/opt/anaconda3/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
